# %% [markdown]
# #  Tầng 1: Data Ingestion
#
# **Mục tiêu:** Đọc file raw `raw/CI_CD Survey Output - Student.csv` và lưu thành `interim/responses.csv` (không thay đổi cấu trúc).
#
# **Input:** `raw/CI_CD Survey Output - Student.csv`
# **Output:** `interim/responses.csv`

# %%
import pandas as pd
from pathlib import Path

from pathlib import Path
# Ensure paths resolve from the project root when notebooks run from notebooks/.
import os
PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
os.chdir(PROJECT_ROOT)
# ── Config ──────────────────────────────────────────────
RAW_FILE = "raw/CI_CD Survey Output - Student.csv"
OUTPUT_FILE = "interim/responses.csv"

# ── Đọc file raw ───────────────────────────────────────
raw_path = Path(RAW_FILE)
if not raw_path.exists():
    raise FileNotFoundError(f" Không tìm thấy file: {raw_path.resolve()}")

df = pd.read_csv(raw_path, encoding="utf-8-sig")

print(f" Đọc thành công: {df.shape[0]} dòng × {df.shape[1]} cột")
print(f"\n Danh sách cột:")
for i, col in enumerate(df.columns, 1):
    print(f"  {i:>2}. {col}")
# Out:
#  Đọc thành công: 164 dòng × 41 cột
#
#  Danh sách cột:
#    1. Dấu thời gian
#    2. Bạn đang học tại trường nào?
#    3. Bạn đang học năm mấy?
#    4. Chuyên ngành hướng đào tạo chính của bạn?
#    5. Lĩnh vực / Sản phẩm chính mà bạn đang thực hiện?
#    6. Bạn đã từng nghe đến thuật ngữ CI/CD(Continuous Integration / Continuous Deployment) chưa?
#    7. Mức độ tự động hóa trong các dự án lập trình mà bạn từng thực hiện là gì?
#    8. Bạn đã từng sử dụng công cụ CI/CD nào trong quá trình học tập hoặc làm dự án cá nhân?
#    9. Bạn đã tiếp cận CI/CD chủ yếu thông qua nguồn nào?
#   10. Bạn sử dụng các công cụ CI/CD đã chọn cho những mục đích nào trong quy trình phát triển phần mềm?
#   11. Theo bạn, CI/CD giúp cải thiện điều gì trong quy trình phát triển phần mềm?
#   12. Trong các dự án lập trình mà bạn từng thực hiện (đồ án, project cá nhân, hoặc project nhóm), bạn cập nhật phiên bản mới của ứng dụng lên môi trường chạy thử (server, hosting, cloud, v.v.) với tần suất như thế nào?
#   13. Kể từ thời điểm bạn hoàn thành việc viết code và đẩy lên hệ thống (commit), mất bao lâu để những thay đổi đó thực sự chạy thành công trên môi trường cho người dùng cuối (Production)?
#   14. Khi dự án của bạn gặp lỗi nghiêm trọng sau khi cập nhật code (ví dụ: ứng dụng không chạy, lỗi server, lỗi chức năng), bạn thường mất bao lâu để khắc phục và đưa hệ thống hoạt động bình thường trở lại?
#   15. Trong các lần bạn cập nhật hoặc triển khai phiên bản mới của dự án (đồ án, project cá nhân, hoặc project nhóm), tỷ lệ gặp lỗi nghiêm trọng khiến hệ thống không hoạt động đúng thường ở mức nào?
#   16. CI/CD giúp tôi tiết kiệm thời gian triển khai trong các dự án học tập
#   17. CI/CD giúp tôi phát hiện lỗi code sớm hơn so với kiểm tra thủ công
#   18. Biết sử dụng CI/CD giúp tôi tự tin hơn khi thực tập hoặc xin việc
#   19. Tôi thấy việc tìm hiểu CI/CD không quá khó so với các kỹ năng lập trình khác
#   20. Tôi có thể tự học CI/CD thông qua tài liệu và hướng dẫn có sẵn trên mạng
#   21. Tôi có thể tự thiết lập một pipeline CI/CD đơn giản sau khi đọc hướng dẫn
#   22.  Bạn bè / đồng học trong nhóm dự án khuyến khích tôi sử dụng CI/CD
#   23. Giảng viên hoặc mentor trong quá trình thực tập đề cao việc áp dụng CI/CD
#   24. CI/CD được coi là kỹ năng tiêu chuẩn mà một lập trình viên chuyên nghiệp cần có
#   25. Chương trình đào tạo tại trường cung cấp đủ kiến thức nền để tôi tiếp cận CI/CD
#   26. Các công cụ CI/CD miễn phí (GitHub Actions, GitLab CI...) đủ để tôi thực hành trong môi trường học tập
#   27. Tôi dễ dàng tìm được sự hỗ trợ khi gặp khó khăn với CI/CD (giảng viên, cộng đồng online, tài liệu...)
#   28. Tôi có ý định áp dụng CI/CD vào các dự án học tập hoặc thực tập sắp tới
#   29. Tôi dự định tự học thêm về CI/CD ngoài chương trình đào tạo chính khoá
#   30. Tôi sẽ ưu tiên tham gia các dự án hoặc nhóm có sử dụng CI/CD
#   31. Tôi đã thực tế cấu hình hoặc sử dụng CI/CD trong ít nhất một dự án
#   32. Tôi thường xuyên dùng CI/CD trong quá trình phát triển phần mềm của mình
#   33. Tôi chủ động đề xuất hoặc thiết lập CI/CD cho nhóm mà không cần ai yêu cầu
#   34. Trong quá trình học tập hoặc thực hiện các dự án lập trình (đồ án, project cá nhân, project nhóm), bạn cảm thấy khó khăn ở những giai đoạn nào của quy trình CI/CD?
#   35. Theo bạn, những khó khăn hoặc thách thức nào khiến sinh viên khó áp dụng CI/CD trong quá trình học tập và làm dự án?
#   36. Theo bạn, điều gì cần được cải thiện để sinh viên dễ tiếp cận và học CI/CD hiệu quả hơn?
#   37. Bạn có đề xuất nào để các trường đại học hoặc giảng viên hỗ trợ sinh viên học và áp dụng CI/CD tốt hơn trong các môn học hoặc dự án?
#   38. Theo bạn, sinh viên cần được trang bị thêm những kiến thức hoặc kỹ năng nào để áp dụng CI/CD hiệu quả trong các dự án phần mềm?
#   39. Bạn có dự định tìm hiểu hoặc áp dụng CI/CD trong các dự án lập trình (đồ án, project cá nhân, project nhóm) trong thời gian tới không?
#   40. Theo bạn, đâu là rào cản lớn nhất khiến sinh viên chưa áp dụng CI/CD trong các dự án lập trình?
#   41. Nếu CI/CD được áp dụng trong các dự án học tập hoặc project cá nhân, bạn mong đợi lợi ích nào nhất?

# %%
# ── Quick Preview ──────────────────────────────────────
df.head(3)
# Out:
#          Dấu thời gian Bạn đang học tại trường nào? Bạn đang học năm mấy?  \
# 0   13/09/2026 1:10:46     Đại học Kinh Tế Quốc Dân                 Năm 2
# 1  12/09/2026 21:31:44   Đại học Giao thông Vận tải                 Năm 4
# 2  12/09/2026 20:15:22     Đại học Kinh Tế Quốc Dân                 Năm 3
#
#   Chuyên ngành hướng đào tạo chính của bạn?  \
# 0                         Kỹ thuật phần mềm
# 1                       Công nghệ thông tin
# 2       Trí tuệ nhân tạo / Khoa học dữ liệu
#
#   Lĩnh vực / Sản phẩm chính mà bạn đang thực hiện?  \
# 0     Phần mềm ứng dụng (Web, Mobile, Desktop App)
# 1     Phần mềm ứng dụng (Web, Mobile, Desktop App)
# 2                Hệ thống AI/Big Data/Data Science
#
#   Bạn đã từng nghe đến thuật ngữ CI/CD(Continuous Integration / Continuous Deployment) chưa?  \
# 0                                  Chưa bao giờ nghe
# 1                     Có nghe qua nhưng chưa hiểu rõ
# 2        Hiểu rõ và có thể giải thích cho người khác
#
#   Mức độ tự động hóa trong các dự án lập trình mà bạn từng thực hiện là gì?    \
# 0                                                NaN
# 1  Tự động hóa một phần nhỏ (ví dụ: chỉ tự động B...
# 2  Tự động hóa một phần nhỏ (ví dụ: chỉ tự động B...
#
#   Bạn đã từng sử dụng công cụ CI/CD nào trong quá trình học tập hoặc làm dự án cá nhân?   \
# 0                                                NaN
# 1                Chưa từng sử dụng công cụ CI/CD nào
# 2                       GitLab CI/CD, GitHub Actions
#
#   Bạn đã tiếp cận CI/CD chủ yếu thông qua nguồn nào?  \
# 0                                                NaN
# 1             Tự tìm hiểu qua tài liệu trên Internet
# 2                      Dự án cá nhân / Đồ án môn học
#
#   Bạn sử dụng các công cụ CI/CD đã chọn cho những mục đích nào trong quy trình phát triển phần mềm?  \
# 0                                                NaN
# 1          Học tập / nghiên cứu / thử nghiệm cá nhân
# 2  Build / Tự động hoá quá trình build, Continuou...
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
#
#   Tôi thường xuyên dùng CI/CD trong quá trình phát triển phần mềm của mình    \
# 0                                                NaN
# 1                                                5.0
# 2                                                4.0
#
#   Tôi chủ động đề xuất hoặc thiết lập CI/CD cho nhóm mà không cần ai yêu cầu    \
# 0                                                NaN
# 1                                                3.0
# 2                                                4.0
#
#   Trong quá trình học tập hoặc thực hiện các dự án lập trình (đồ án, project cá nhân, project nhóm), bạn cảm thấy khó khăn ở những giai đoạn nào của quy trình CI/CD?   \
# 0                                                NaN
# 1  Tích hợp liên tục (CI - Integration), Xây dụng...
# 2              Xây dụng (Build), Giám sát & Phản hồi
#
#   Theo bạn, những khó khăn hoặc thách thức nào khiến sinh viên khó áp dụng CI/CD trong quá trình học tập và làm dự án?   \
# 0                                                NaN
# 1  Việc thiết lập và cấu hình công cụ CI/CD khá p...
# 2  Thiếu kiến thức hoặc kỹ năng về DevOps/CI/CD, ...
#
#   Theo bạn, điều gì cần được cải thiện để sinh viên dễ tiếp cận và học CI/CD hiệu quả hơn?    \
# 0                                                NaN
# 1                                     Toi không biet
# 2  Sinh viên cần hiểu rõ một quy trình phát triển...
#
#    Bạn có đề xuất nào để các trường đại học hoặc giảng viên hỗ trợ sinh viên học và áp dụng CI/CD tốt hơn trong các môn học hoặc dự án?    \
# 0                                                NaN
# 1                                              Không
# 2  Cung cấp tài liệu hướng dẫn kết hợp yêu cầu dự...
#
#    Theo bạn, sinh viên cần được trang bị thêm những kiến thức hoặc kỹ năng nào để áp dụng CI/CD hiệu quả trong các dự án phần mềm?    \
# 0                                                NaN
# 1                                         Khong biet
# 2                                Cách vận hành CI/CD
#
#    Bạn có dự định tìm hiểu hoặc áp dụng CI/CD trong các dự án lập trình (đồ án, project cá nhân, project nhóm) trong thời gian tới không?   \
# 0                     Chưa có kế hoạch áp dụng CI/CD
# 1                                                NaN
# 2                                                NaN
#
#    Theo bạn, đâu là rào cản lớn nhất khiến sinh viên chưa áp dụng CI/CD trong các dự án lập trình?   \
# 0  Thiếu kiến thức hoặc kỹ năng về CI/CD và DevOp...
# 1                                                NaN
# 2                                                NaN
#
#    Nếu CI/CD được áp dụng trong các dự án học tập hoặc project cá nhân, bạn mong đợi lợi ích nào nhất?
# 0  Giảm bớt các công việc thủ công lặp đi lặp lại...
# 1                                                NaN
# 2                                                NaN
#
# [3 rows x 41 columns]

# %%
# ── Lưu ra interim/responses.csv ──────────────────────────────
df.to_csv(OUTPUT_FILE, index=False, encoding="utf-8-sig")

# ── Verify ────────────────────────────────────────────
verify = pd.read_csv(OUTPUT_FILE, encoding="utf-8-sig")
assert verify.shape == df.shape, " File output không khớp shape!"
print(f" Đã lưu thành công: {OUTPUT_FILE}")
print(f"   Shape: {verify.shape[0]} dòng × {verify.shape[1]} cột")
# Out:
#  Đã lưu thành công: interim/responses.csv
#    Shape: 164 dòng × 41 cột
