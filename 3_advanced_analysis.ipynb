# %% [markdown]
# #  Tầng 3d: Advanced Grouping & Correlation Analysis
#
# **Mục tiêu:** Thực hiện phân tích nhóm chéo nâng cao, ánh xạ các chỉ số **DORA Metrics** và kiểm định mô hình chấp nhận công nghệ **UTAUT** để kiểm chứng các giả thuyết khoa học về lợi ích thực tế của CI/CD.
#
# **Các nhóm phân tích chính:**
# 1. **Nhóm 1 - DORA metrics** (Hướng 1 - 4)
# 2. **Nhóm 2 - Nhận thức & Thực hành** (Hướng 5 - 7)
# 3. **Nhóm 3 - Nguồn học & Hiệu quả** (Hướng 8 - 10)
# 4. **Nhóm 4 - Mô hình UTAUT** (Hướng 11 - 14)
# 5. **Nhóm 5 - Rào cản & Đề xuất** (Hướng 15 - 18)
# 6. **Nhóm 6 - Adoption Readiness** (Hướng 19 - 20)
#
# **Input:** `multiple_answers_processed.csv`
# **Output:** 20 biểu đồ học thuật nâng cao lưu vào thư mục `output/` và tệp báo cáo tổng hợp `ADVANCED_ANALYSIS_REPORT.md`

# %%
# Chạy toàn bộ kịch bản phân tích chéo nâng cao
# %run advanced_analysis.py
# Out:
# 🚀 Loaded multiple_answers_processed.csv: 151 dòng x 92 cột
# 📊 Phân loại sử dụng CI/CD: Đã dùng: 66 (43.7%) | Chưa dùng: 85 (56.3%)
#
# --- Nhóm 1: Phân tích DORA Metrics ---
# 💡 Hướng 1: DORA Performance Classification
# D:\NCKH_thay_Thao\data\advanced_analysis.py:141: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=dora_counts.index, y=dora_counts.values, palette=COLORS_DORA, ax=ax)
# 💡 Hướng 2: CI/CD adoption vs DORA score
#    T-test comparison: t=9.518, p=0.00000
# D:\NCKH_thay_Thao\data\advanced_analysis.py:161: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="has_used_cicd", y="dora_score", palette="Set2", ax=ax, width=0.5)
# D:\NCKH_thay_Thao\data\advanced_analysis.py:163: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Chưa sử dụng CI/CD", "Đã sử dụng CI/CD"])
# 💡 Hướng 3: DORA score theo năm học / trường
# D:\NCKH_thay_Thao\data\advanced_analysis.py:175: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Q2_year", y="dora_score", order=year_order, palette="Blues_d", errorbar="ci", ax=axes[0])
# D:\NCKH_thay_Thao\data\advanced_analysis.py:176: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=15)
# D:\NCKH_thay_Thao\data\advanced_analysis.py:182: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Q1_university", y="dora_score", order=uni_order, palette="Purples_d", errorbar="ci", ax=axes[1])
# D:\NCKH_thay_Thao\data\advanced_analysis.py:183: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=30, ha="right")
# 💡 Hướng 4: DORA vs Likert benefits
# --- Nhóm 2: Nhận thức & Thực hành ---
# 💡 Hướng 5: Phễu nhận thức theo năm học
# 💡 Hướng 6: Knowing-Doing Gap
#    Analyzing barriers for 'Know but not do' group...
#    Số sinh viên Biết khái niệm nhưng Chưa từng dùng tool: 8
# D:\NCKH_thay_Thao\data\advanced_analysis.py:286: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=barrier_sums_gap.values, y=barrier_sums_gap.index, palette="Reds_d", ax=ax)
# 💡 Hướng 7: Mức tự động hóa vs công cụ đã dùng
# --- Nhóm 3: Nguồn học & Hiệu quả ---
# 💡 Hướng 8: Nguồn học vs mức tự động hóa thực tế
# 💡 Hướng 9: Nguồn học vs DORA score
# D:\NCKH_thay_Thao\data\advanced_analysis.py:374: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_source_auto, x="Tỉ lệ TĐH Cao/Tối ưu (%)", y="Nguồn tiếp cận", palette="Greens_d", ax=ax)
# 💡 Hướng 10: Nguồn học vs tự tin nghề nghiệp
#
# --- Nhóm 4: Phân tích mô hình UTAUT ---
# 💡 Hướng 11: Self-efficacy -> Actual use
# D:\NCKH_thay_Thao\data\advanced_analysis.py:423: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_source_conf, x="Tự tin xin việc (Q17)", y="Nguồn tiếp cận", palette="YlOrBr_d", ax=ax)
# 💡 Hướng 12: Social influence -> Intention
# 💡 Hướng 13: Facilitating conditions -> Actual use
# 💡 Hướng 14: Intention vs Actual use gap
# --- Nhóm 5: Phân tích Rào cản & Đề xuất ---
# 💡 Hướng 15: Rào cản theo mức nhận thức
# 💡 Hướng 16: Rào cản theo năm học
# 💡 Hướng 17: Giai đoạn khó nhất của pipeline
# 💡 Hướng 18: Kỳ vọng vs thực tế
# D:\NCKH_thay_Thao\data\advanced_analysis.py:590: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(diff_sums.index, rotation=15, ha="right", fontsize=9)
# --- Nhóm 6: Adoption Readiness ---
# 💡 Hướng 19: Adoption Readiness Index theo năm học
# D:\NCKH_thay_Thao\data\advanced_analysis.py:657: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Q2_year", y="adoption_readiness", order=year_order, palette="autumn", ax=ax)
# 💡 Hướng 20: Adoption Readiness vs điều kiện hỗ trợ
# 📝 Đang tạo tệp báo cáo tổng kết advanced_analysis_report.md...
# 🎉 Đã tạo thành công báo cáo ADVANCED_ANALYSIS_REPORT.md!
# ✅ Toàn bộ 22 biểu đồ phân tích chéo đã được tạo thành công trong thư mục output/3_advanced_grouping_correlation/
